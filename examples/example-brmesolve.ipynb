# %% [markdown]
# # Bloch-Redfield master equation examples

# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from qutip import *

# %% [markdown]
# ## Two-level system

# %%
delta = 0.0 * 2 * pi
epsilon = 0.5 * 2 * pi
gamma = 0.25
times = linspace(0, 10, 100)

# %%
H = delta/2 * sigmax() + epsilon/2 * sigmaz()
H
# Out:
# Quantum object: dims = [[2], [2]], shape = [2, 2], type = oper, isherm = True
# Qobj data =
# [[ 1.57079633  0.        ]
#  [ 0.         -1.57079633]]

# %%
psi0 = (2 * basis(2, 0) + basis(2, 1)).unit()

# %%
c_ops = [sqrt(gamma) * sigmam()]
a_ops = [sigmax()]

# %%
e_ops = [sigmax(), sigmay(), sigmaz()]

# %%
result_me = mesolve(H, psi0, times, c_ops, e_ops)

# %%
result_brme = brmesolve(H, psi0, times, a_ops, e_ops, spectra_cb=[lambda w : gamma * (w > 0)])

# %%
plot_expectation_values([result_me, result_brme]);

# %%
b = Bloch()
b.add_points(result_me.expect, meth='l')
b.add_points(result_brme.expect, meth='l')
b.make_sphere()

# %% [markdown]
# ## Harmonic oscillator

# %%
N = 10

w0 = 1.0 * 2 * pi
g = 0.05 * w0
kappa = 0.15

times = linspace(0, 25, 1000)

# %%
a = destroy(N)

# %%
H = w0 * a.dag() * a + g * (a + a.dag())

# %%
# start in a superposition state
psi0 = ket2dm((basis(N, 4) + basis(N, 2) + basis(N,0)).unit())

# %%
c_ops = [sqrt(kappa) * a]
a_ops = [a + a.dag()]

# %%
e_ops = [a.dag() * a, a + a.dag()]

# %% [markdown]
# ### Zero temperature

# %%
result_me = mesolve(H, psi0, times, c_ops, e_ops)

# %%
result_brme = brmesolve(H, psi0, times, a_ops, e_ops, spectra_cb=[lambda w : kappa * (w > 0)])

# %%
plot_expectation_values([result_me, result_brme]);

# %% [markdown]
# ### Finite temperature

# %%
times = linspace(0, 25, 250)

# %%
n_th = 1.5
c_ops = [sqrt(kappa * (n_th + 1)) * a, sqrt(kappa * n_th) * a.dag()]

# %%
result_me = mesolve(H, psi0, times, c_ops, e_ops)

# %%
w_th = w0/log(1 + 1/n_th)

def S_w(w):
    if w >= 0:
        return (n_th + 1) * kappa
    else:
        return (n_th + 1) * kappa * exp(w / w_th)

# %%
result_brme = brmesolve(H, psi0, times, a_ops, e_ops, [S_w])

# %%
plot_expectation_values([result_me, result_brme]);

# %% [markdown]
# ### Storing states instead of expectation values

# %%
result_me = mesolve(H, psi0, times, c_ops, [])

# %%
result_brme = brmesolve(H, psi0, times, a_ops, [], [S_w])

# %%
n_me = expect(a.dag() * a, result_me.states)

# %%
n_brme = expect(a.dag() * a, result_brme.states)

# %%
fig, ax = plt.subplots()

ax.plot(times, n_me, label='me')
ax.plot(times, n_brme, label='brme')
ax.legend()
ax.set_xlabel("t");

# %% [markdown]
# ## Atom-Cavity

# %%
N = 10
a = tensor(destroy(N), identity(2))
sm = tensor(identity(N), destroy(2))
psi0 = ket2dm(tensor(basis(N, 1), basis(2, 0)))
a_ops = [(a + a.dag())]
e_ops = [a.dag() * a, sm.dag() * sm]

# %% [markdown]
# ### Weak coupling

# %%
w0 = 1.0 * 2 * pi
g = 0.05 * 2 * pi
kappa = 0.05
times = linspace(0, 5 * 2 * pi / g, 1000)

# %%
c_ops = [sqrt(kappa) * a]
H = w0 * a.dag() * a + w0 * sm.dag() * sm + g * (a + a.dag()) * (sm + sm.dag())

# %%
result_me = mesolve(H, psi0, times, c_ops, e_ops)

# %%
result_brme = brmesolve(H, psi0, times, a_ops, e_ops, spectra_cb=[lambda w : kappa*(w > 0)])

# %%
plot_expectation_values([result_me, result_brme]);

# %% [markdown]
# In the weak coupling regime there is no significant difference between the Lindblad master equation and the Bloch-Redfield master equation.

# %% [markdown]
# ### Strong coupling

# %%
w0 = 1.0 * 2 * pi
g = 0.75 * 2 * pi
kappa = 0.05
times = linspace(0, 5 * 2 * pi / g, 1000)

# %%
c_ops = [sqrt(kappa) * a]
H = w0 * a.dag() * a + w0 * sm.dag() * sm + g * (a + a.dag()) * (sm + sm.dag())

# %%
result_me = mesolve(H, psi0, times, c_ops, e_ops)

# %%
result_brme = brmesolve(H, psi0, times, a_ops, e_ops, spectra_cb=[lambda w : kappa*(w > 0)])

# %%
plot_expectation_values([result_me, result_brme]);

# %% [markdown]
# In the strong coupling regime there are some corrections to the Lindblad master equation that is due to the fact system eigenstates are hybridized states with both atomic and cavity contributions.

# %% [markdown]
# ## Versions

# %%
from qutip.ipynbtools import version_table

version_table()
# Out:
# <table><tr><th>Software</th><th>Version</th></tr><tr><td>Numpy</td><td>1.7.1</td></tr><tr><td>IPython</td><td>1.1.0</td></tr><tr><td>Cython</td><td>0.19</td></tr><tr><td>matplotlib</td><td>1.2.1</td></tr><tr><td>OS</td><td>posix [linux]</td></tr><tr><td>SciPy</td><td>0.12.0</td></tr><tr><td>QuTiP</td><td>2.3.0.dev-e47d8b1</td></tr><tr><td>Python</td><td>3.3.2+ (default, Oct  9 2013, 14:50:09)
# [GCC 4.8.1]</td></tr><tr><td colspan='2'>Tue Dec 10 16:23:27 2013 JST</td></tr></table>
