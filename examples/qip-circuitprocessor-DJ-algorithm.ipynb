# %% [markdown]
# # The Deutsch–Jozsa algorithm with CircuitProcessor

# %%
import numpy as np
from qutip.qip.device import OptPulseProcessor, LinearSpinChain
from qutip.qip import QubitCircuit
from qutip.operators import sigmaz, sigmax, identity
from qutip.tensor import tensor
from qutip.states import basis
from qutip.qobj import ptrace
basis00 = tensor([basis(2,0), basis(2,0)])

# %% [markdown]
# In this example, we demonstrate how to use the sub-classes of CircuitProcessor to implement simple quantum algorithms. Those classes have a common method `load_circuit` that can transfer a `QubitCircuit` object into pulse sequences. They are either base on physical model or use the `qutip.control` module.
#
# ## The Deutsch–Jozsa algorithm
# The Deutsch–Jozsa algorithm is the simplest quantum algorithm that offers an exponential speed-up compared to the classical one. It assumes that we have a function $f:\{0,1\}^n \rightarrow \{0,1\}$ which is either balanced or constant. Constant means that $f(x)$ is either 1 or 0 for all inputs while balanced means that $f(x)$ is 1 for half of the input domain and 0 for the other half. A more rigorous definition can be found at https://en.wikipedia.org/wiki/Deutsch%E2%80%93Jozsa_algorithm.
#
# The implementation of the Deutsch–Jozsa algorithm clues $n$ input qubits and 1 ancilla initialised in state $1$. At the end of the algorithm, the first $n$ qubits are measured on the computational basis. If the function is constant, the result will be $0$ for all $n$ qubits. If balanced, $\left|00...0\right\rangle$ will never be measured.
# The following example is implmented for the balenced function $f:\{00,01,10,11\} \rightarrow \{0,1\}$, where $f(00)=f(11)=0$ and $f(01)=f(10)=1$. This function is balanced, so the probability of measuring state $\left|00\right\rangle$ should be 0.

# %%
qc = QubitCircuit(N=3)
qc.add_gate("SNOT", targets=0)
qc.add_gate("SNOT", targets=1)
qc.add_gate("SNOT", targets=2)

# function f(x)
qc.add_gate("CNOT", controls=0, targets=2)
qc.add_gate("CNOT", controls=1, targets=2)

qc.add_gate("SNOT", targets=0)
qc.add_gate("SNOT", targets=1)

# %% [markdown]
# ## With OptPulseProcessor

# %%
setting_args = {"SNOT": {"num_tslots": 5, "evo_time": 1},
                "CNOT": {"num_tslots": 12, "evo_time": 5}}
proc = OptPulseProcessor(N=3)
proc.add_ctrl(sigmaz(), cyclic_permutation=True)
proc.add_ctrl(sigmax(), cyclic_permutation=True)
proc.add_ctrl(tensor([sigmax(), sigmax(), identity(2)]))
proc.add_ctrl(tensor([identity(2), sigmax(), sigmax()]))
proc.load_circuit(qc, setting_args=setting_args, merge_gates=False, verbose=True,
                  amp_ubound=5, amp_lbound=0);
# Out:
# ********** Gate 0 **********
# Final fidelity error 1.1348133543975791e-10
# Final gradient normal 4.527500406730697e-06
# Terminated due to function converged
# Number of iterations 14
# ********** Gate 1 **********
# Final fidelity error 4.1033386688482665e-09
# Final gradient normal 1.356791731984262e-05
# Terminated due to function converged
# Number of iterations 33
# ********** Gate 2 **********
# Final fidelity error 3.627576017350975e-11
# Final gradient normal 8.916128194294868e-06
# Terminated due to Goal achieved
# Number of iterations 13
# ********** Gate 3 **********
# Final fidelity error 4.355660365717995e-08
# Final gradient normal 0.00010336874776374725
# Terminated due to function converged
# Number of iterations 93
# ********** Gate 4 **********
# Final fidelity error 2.9307171964809697e-06
# Final gradient normal 0.0007618278753467284
# Terminated due to function converged
# Number of iterations 50
# ********** Gate 5 **********
# Final fidelity error 1.28820398792584e-10
# Final gradient normal 4.7123815420490484e-06
# Terminated due to function converged
# Number of iterations 15
# ********** Gate 6 **********
# Final fidelity error 4.364875128004542e-11
# Final gradient normal 1.5142207362718403e-05
# Terminated due to Goal achieved
# Number of iterations 12

# %%
proc.plot_pulses(title="Control pulse of OptPulseProcessor", figsize=(8, 4), dpi=100);

# %%
# Without decoherence
psi0 = tensor([basis(2, 0), basis(2, 0), basis(2, 1)])
result = proc.run_state(rho0=psi0)
print("Probability of measuring state 00:")
print(np.real((basis00.dag() * ptrace(result.states[-1], [0,1]) * basis00)[0,0]))
# Out:
# Probability of measuring state 00:
# 5.1685843711029794e-08

# %%
# With decoherence
proc.t1 = 100
proc.t2 = 30
psi0 = tensor([basis(2, 0), basis(2, 0), basis(2, 1)])
result = proc.run_state(rho0=psi0)
print("Probability of measuring state 00:")
print(np.real((basis00.dag() * ptrace(result.states[-1], [0,1]) * basis00)[0,0]))
# Out:
# Probability of measuring state 00:
# 0.10510140771667911

# %% [markdown]
# ## With SpinChain

# %%
proc2 = LinearSpinChain(3)
proc2.load_circuit(qc);

# %%
proc2.plot_pulses(title="Control pulse of Spin chain");

# %% [markdown]
# The first three pulse periods are for the three hadamard gates, they are followed by two long periods for CNOT gate and then again two Hadamard.

# %%
# Without decoherence
psi0 = tensor([basis(2, 0), basis(2, 0), basis(2, 1)])
result = proc2.run_state(rho0 = psi0)
print("Probability of measuring state 00:")
print(np.real((basis00.dag() * ptrace(result.states[-1], [0,1]) * basis00)[0,0]))
# Out:
# Probability of measuring state 00:
# 1.800211315512652e-09

# %%
# With decoherence
proc2.t1 = 100
proc2.t2 = 30
psi0 = tensor([basis(2, 0), basis(2, 0), basis(2, 1)])
result = proc2.run_state(rho0 = psi0)
print("Probability of measuring state 00:")
print(np.real((basis00.dag() * ptrace(result.states[-1], [0,1]) * basis00)[0,0]))
# Out:
# Probability of measuring state 00:
# 0.16615828432135332

# %%
from qutip.ipynbtools import version_table
version_table()
# Out:
# <table><tr><th>Software</th><th>Version</th></tr><tr><td>QuTiP</td><td>4.5.0.dev0+c50c4bc9</td></tr><tr><td>Numpy</td><td>1.16.2</td></tr><tr><td>SciPy</td><td>1.2.1</td></tr><tr><td>matplotlib</td><td>3.0.3</td></tr><tr><td>Cython</td><td>0.29.12</td></tr><tr><td>Number of CPUs</td><td>12</td></tr><tr><td>BLAS Info</td><td>INTEL MKL</td></tr><tr><td>IPython</td><td>7.4.0</td></tr><tr><td>Python</td><td>3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]</td></tr><tr><td>OS</td><td>nt [win32]</td></tr><tr><td colspan='2'>Mon Aug 19 11:58:41 2019 W. Europe Daylight Time</td></tr></table>
