# %% [markdown]
# # Running the Deutsch–Jozsa algorithm on the NISQ device simulator

# %%
import numpy as np
from qutip.qip.device import OptPulseProcessor, LinearSpinChain
from qutip.qip import QubitCircuit
from qutip.operators import sigmaz, sigmax, identity
from qutip.tensor import tensor
from qutip.states import basis
from qutip.qobj import ptrace
basis00 = tensor([basis(2,0), basis(2,0)])

# %% [markdown]
# In this example, we demonstrate how to simulate simple quantum algorithms on a qauntum hardware with QuTiP. The simulators are defined in the class `Processor`(and its sub-classes). `Processor` is a representation of a quantum device. The interaction of the quantum systems such as qubits is defined by the Hamiltonian. One can set the amplitude of the interaction by the attribute `coeff` which corresponds to the pulse intensity of the control system. For more details please refer to the introduction notebook of NISQ simulation with QuTiP.
#
# In this example, we won't set the interaction strength by ourselves. Instead, we give it a sequence of gates, i.e. a `QubitCircuit`, and let the Processor find the desired pulses. The `Processor` class has a method `load_circuit` that can transfer a `QubitCircuit` object into a control pulse sequence. Different sub-class of `Processor` find their pulses in different ways. We show two examples here, one is based on a physical model and the other uses the `qutip.control` module. For each case, we also compare the result with or without noise by defining the `t1` and `t2` time of the device.
#
# ## The Deutsch–Jozsa algorithm
# The Deutsch–Jozsa algorithm is the simplest quantum algorithm that offers an exponential speed-up compared to the classical one. It assumes that we have a function $f:\{0,1\}^n \rightarrow \{0,1\}$ which is either balanced or constant. Constant means that $f(x)$ is either 1 or 0 for all inputs while balanced means that $f(x)$ is 1 for half of the input domain and 0 for the other half. A more rigorous definition can be found at https://en.wikipedia.org/wiki/Deutsch%E2%80%93Jozsa_algorithm.
#
# The implementation of the Deutsch–Jozsa algorithm clues $n$ input qubits and 1 ancilla initialised in state $1$. At the end of the algorithm, the first $n$ qubits are measured on the computational basis. If the function is constant, the result will be $0$ for all $n$ qubits. If balanced, $\left|00...0\right\rangle$ will never be measured.
# The following example is implemented for the balanced function $f:\{00,01,10,11\} \rightarrow \{0,1\}$, where $f(00)=f(11)=0$ and $f(01)=f(10)=1$. This function is balanced, so the probability of measuring state $\left|00\right\rangle$ should be 0.

# %%
qc = QubitCircuit(N=3)
qc.add_gate("SNOT", targets=0)
qc.add_gate("SNOT", targets=1)
qc.add_gate("SNOT", targets=2)

# function f(x)
qc.add_gate("CNOT", controls=0, targets=2)
qc.add_gate("CNOT", controls=1, targets=2)

qc.add_gate("SNOT", targets=0)
qc.add_gate("SNOT", targets=1)

# %% [markdown]
# ## Using the optimal control module to find the pulse
# This is integrated into the sub-class `OptPulseProcessor` which use methods in the optimal control module to find the pulse sequence for the desired gates. It can find the optimal pulse either for the whole unitary evolution or for each gate. Here we choose the second option.

# %%
setting_args = {"SNOT": {"num_tslots": 5, "evo_time": 1},
                "CNOT": {"num_tslots": 12, "evo_time": 5}}
processor = OptPulseProcessor(N=3)
processor.add_ctrl(sigmaz(), cyclic_permutation=True)
processor.add_ctrl(sigmax(), cyclic_permutation=True)
processor.add_ctrl(tensor([sigmax(), sigmax(), identity(2)]))
processor.add_ctrl(tensor([identity(2), sigmax(), sigmax()]))
processor.load_circuit(qc, setting_args=setting_args, merge_gates=False, verbose=True,
                  amp_ubound=5, amp_lbound=0);
# Out:
# ********** Gate 0 **********
# Final fidelity error 0.29289321987475736
# Final gradient normal 2.5865876888915288e-05
# Terminated due to function converged
# Number of iterations 22
# ********** Gate 1 **********
# Final fidelity error 1.6381196399350983e-10
# Final gradient normal 7.186278147227127e-06
# Terminated due to function converged
# Number of iterations 19
# ********** Gate 2 **********
# Final fidelity error 1.2814560523821683e-10
# Final gradient normal 6.24994082154814e-06
# Terminated due to function converged
# Number of iterations 17
# ********** Gate 3 **********
# Final fidelity error 4.3528445200502475e-06
# Final gradient normal 0.00026126795607026335
# Terminated due to function converged
# Number of iterations 125
# ********** Gate 4 **********
# Final fidelity error 1.1785816114606718e-05
# Final gradient normal 0.00129164446889679
# Terminated due to function converged
# Number of iterations 67
# ********** Gate 5 **********
# Final fidelity error 8.870826295748202e-11
# Final gradient normal 1.628843231955956e-05
# Terminated due to Goal achieved
# Number of iterations 14
# ********** Gate 6 **********
# Final fidelity error 7.619915809442546e-11
# Final gradient normal 8.120639714703255e-06
# Terminated due to Goal achieved
# Number of iterations 17

# %% [markdown]
# To quickly visualize the pulse, `Processor` has a method called `plot_pulses`. In the figure, bellow, each colour represents the pulse sequence of one control Hamiltonian in the system as a function of time. In each time interval, the pulse remains constant.

# %%
processor.plot_pulses(title="Control pulse of OptPulseProcessor", figsize=(8, 4), dpi=100);

# %% [markdown]
# To simulate the evolution, we only need to call the method `run_state` which calls the open system solver in QuTiP and calculate the time evolution.
# ### Without decoherence

# %%
psi0 = tensor([basis(2, 0), basis(2, 0), basis(2, 1)])
result = processor.run_state(rho0=psi0)
print("Probability of measuring state 00:")
print(np.real((basis00.dag() * ptrace(result.states[-1], [0,1]) * basis00)[0,0]))
# Out:
# Probability of measuring state 00:
# 1.0269506587219765e-05

# %% [markdown]
# ### With decoherence

# %%
processor.t1 = 100
processor.t2 = 30
psi0 = tensor([basis(2, 0), basis(2, 0), basis(2, 1)])
result = processor.run_state(rho0=psi0)
print("Probability of measuring state 00:")
print(np.real((basis00.dag() * ptrace(result.states[-1], [0,1]) * basis00)[0,0]))
# Out:
# Probability of measuring state 00:
# 0.13677375647842338

# %% [markdown]
# ## Generating pulse based on quantum computing model
# In this example, we use the sub-class `LinearSpinChain`. It will find the pulse based on the Hamiltonian available on a linear spin chain.

# %%
processor2 = LinearSpinChain(3)
processor2.load_circuit(qc);

# %%
processor2.plot_pulses(title="Control pulse of Spin chain");

# %% [markdown]
# The first three pulse periods are for the three Hadamard gates, they are followed by two long periods for the CNOT gates and then again two Hadamard.

# %% [markdown]
# ### Without decoherence

# %%
psi0 = tensor([basis(2, 0), basis(2, 0), basis(2, 1)])
result = processor2.run_state(rho0 = psi0)
print("Probability of measuring state 00:")
print(np.real((basis00.dag() * ptrace(result.states[-1], [0,1]) * basis00)[0,0]))
# Out:
# Probability of measuring state 00:
# 1.800211315512652e-09

# %% [markdown]
# ### With decoherence

# %%
processor2.t1 = 100
processor2.t2 = 30
psi0 = tensor([basis(2, 0), basis(2, 0), basis(2, 1)])
result = processor2.run_state(rho0 = psi0)
print("Probability of measuring state 00:")
print(np.real((basis00.dag() * ptrace(result.states[-1], [0,1]) * basis00)[0,0]))
# Out:
# Probability of measuring state 00:
# 0.16615828432135332

# %%
from qutip.ipynbtools import version_table
version_table()
# Out:
# <table><tr><th>Software</th><th>Version</th></tr><tr><td>QuTiP</td><td>4.5.0.dev0+c50c4bc9</td></tr><tr><td>Numpy</td><td>1.16.2</td></tr><tr><td>SciPy</td><td>1.2.1</td></tr><tr><td>matplotlib</td><td>3.0.3</td></tr><tr><td>Cython</td><td>0.29.12</td></tr><tr><td>Number of CPUs</td><td>12</td></tr><tr><td>BLAS Info</td><td>INTEL MKL</td></tr><tr><td>IPython</td><td>7.4.0</td></tr><tr><td>Python</td><td>3.7.3 (default, Mar 27 2019, 17:13:21) [MSC v.1915 64 bit (AMD64)]</td></tr><tr><td>OS</td><td>nt [win32]</td></tr><tr><td colspan='2'>Mon Aug 19 11:58:41 2019 W. Europe Daylight Time</td></tr></table>
