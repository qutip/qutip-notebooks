# %% [markdown]
# # GRAPE calculation of control fields for single-qubit rotation

# %% [markdown]
# Robert Johansson (robert@riken.jp)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import time
import numpy as np
from numpy import pi

# %%
from qutip import *
from qutip.control import *

# %%
T = 1
times = np.linspace(0, T, 100)

# %%
theta, phi = np.random.rand(2)

# %%
# target unitary transformation (random single qubit rotation)
U = rz(phi) * rx(theta); U
# Out:
# Quantum object: dims = [[2], [2]], shape = [2, 2], type = oper, isherm = False
# Qobj data =
# [[ 0.90518034-0.19177998j -0.07861705-0.37106381j]
#  [ 0.07861705-0.37106381j  0.90518034+0.19177998j]]

# %%
R = 150
H_ops = [sigmax(), sigmay(), sigmaz()]

H_labels = [r'$u_{x}$',
            r'$u_{y}$',
            r'$u_{z}$',
        ]

# %%
H0 = 0 * pi * sigmaz()

# %% [markdown]
# # GRAPE

# %%
from qutip.control.grape import plot_grape_control_fields, _overlap
from qutip.control.cy_grape import cy_overlap
from qutip.control.grape import cy_grape_unitary, grape_unitary_adaptive

# %%
from scipy.interpolate import interp1d
from qutip.ui.progressbar import TextProgressBar

# %%
u0 = np.array([np.random.rand(len(times)) * 2 * pi * 0.005 for _ in range(len(H_ops))])

u0 = [np.convolve(np.ones(10)/10, u0[idx,:], mode='same') for idx in range(len(H_ops))]

# %%
result = cy_grape_unitary(U, H0, H_ops, R, times, u_start=u0, eps=2*pi/T, phase_sensitive=False,
                          progress_bar=TextProgressBar())
# Out:
# 10.0%. Run time:  14.74s. Est. time left: 00:00:02:12
# 20.0%. Run time:  29.01s. Est. time left: 00:00:01:56
# 30.0%. Run time:  43.19s. Est. time left: 00:00:01:40
# 40.0%. Run time:  57.40s. Est. time left: 00:00:01:26
# 50.0%. Run time:  71.64s. Est. time left: 00:00:01:11
# 60.0%. Run time:  85.86s. Est. time left: 00:00:00:57
# 70.0%. Run time: 100.09s. Est. time left: 00:00:00:42
# 80.0%. Run time: 114.31s. Est. time left: 00:00:00:28
# 90.0%. Run time: 128.63s. Est. time left: 00:00:00:14
# Total run time: 141.95s

# %% [markdown]
# ## Plot control fields for iSWAP gate in the presense of single-qubit tunnelling

# %%
plot_grape_control_fields(times, result.u[:,:,:] / (2 * pi), H_labels, uniform_axes=True);

# %%
# target unitary
U
# Out:
# Quantum object: dims = [[2], [2]], shape = [2, 2], type = oper, isherm = False
# Qobj data =
# [[ 0.90518034-0.19177998j -0.07861705-0.37106381j]
#  [ 0.07861705-0.37106381j  0.90518034+0.19177998j]]

# %%
# unitary from grape pulse
result.U_f
# Out:
# Quantum object: dims = [[2], [2]], shape = [2, 2], type = oper, isherm = False
# Qobj data =
# [[ 0.90518034-0.19177998j -0.07861705-0.37106381j]
#  [ 0.07861705-0.37106381j  0.90518034+0.19177998j]]

# %%
# target / result overlap
_overlap(U, result.U_f).real, abs(_overlap(U, result.U_f))**2
# Out:
# (0.99999999999999867, 0.99999999999999734)

# %% [markdown]
# ### Verify correctness of the Hamiltonian pulses by integration

# %%
c_ops = []

# %%
U_f_numerical = propagator(result.H_t, times[-1], c_ops, args={})

# %%
U_f_numerical
# Out:
# Quantum object: dims = [[2], [2]], shape = [2, 2], type = oper, isherm = False
# Qobj data =
# [[ 0.90891817-0.19123392j -0.07345164-0.36318342j]
#  [ 0.07345164-0.36318342j  0.90891817+0.19123392j]]

# %%
_overlap(U, U_f_numerical)
# Out:
# (0.99994847423414779+0j)

# %% [markdown]
# # Bloch sphere dynamics

# %%
psi0 = basis(2, 0)
e_ops = [sigmax(), sigmay(), sigmaz()]

# %%
me_result = mesolve(result.H_t, psi0, times, c_ops, e_ops)

# %%
b = Bloch()

b.add_points(me_result.expect)

b.add_states(psi0)
b.add_states(U * psi0)
b.render()

# %% [markdown]
# # Process tomography

# %% [markdown]
# ## Ideal gate

# %%
op_basis = [[qeye(2), sigmax(), sigmay(), sigmaz()]]
op_label = [["i", "x", "y", "z"]]

# %%
fig = plt.figure(figsize=(8,6))

U_ideal = spre(U) * spost(U.dag())

chi = qpt(U_ideal, op_basis)

fig = qpt_plot_combined(chi, op_label, fig=fig, threshold=0.001)

# %% [markdown]
# ## Gate calculated using GRAPE

# %%
fig = plt.figure(figsize=(8,6))

U_ideal = spre(result.U_f) * spost(result.U_f.dag())

chi = qpt(U_ideal, op_basis)

fig = qpt_plot_combined(chi, op_label, fig=fig, threshold=0.001)

# %% [markdown]
# ## Versions

# %%
from qutip.ipynbtools import version_table

version_table()
# Out:
# <table><tr><th>Software</th><th>Version</th></tr><tr><td>Python</td><td>3.4.0 (default, Apr 11 2014, 13:05:11)
# [GCC 4.8.2]</td></tr><tr><td>IPython</td><td>2.3.0</td></tr><tr><td>Numpy</td><td>1.9.0</td></tr><tr><td>OS</td><td>posix [linux]</td></tr><tr><td>matplotlib</td><td>1.4.x</td></tr><tr><td>QuTiP</td><td>3.1.0.dev-ebe0001</td></tr><tr><td>SciPy</td><td>0.14.0</td></tr><tr><td>Cython</td><td>0.20.1</td></tr><tr><td colspan='2'>Tue Oct 07 13:57:45 2014 JST</td></tr></table>
