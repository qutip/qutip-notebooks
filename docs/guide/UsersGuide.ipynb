# %% [markdown]
# #Users Guide

# %% [markdown]
# ##Table of Contents
#
# - [Guide Overview](#about)
# - [Basic Operations on Quantum Objects](BasicOperations.ipynb)
#     - [First Things First](BasicOperations.ipynb#first)
#     - [Quantum Object Class](BasicOperations.ipynb#qobj)
#     - [Functions on the Qobj Class](BasicOperations.ipynb#functions)
# - [Manipulating States and Operators](StatesOperators.ipynb)
#     - [Introduction](StatesOperators.ipynb#intro)
#     - [State Vectors (Kets or Bras)](StatesOperators.ipynb#states)
#     - [Density Matrices](StatesOperators.ipynb#density)
#     - [Qubit (two-level) Systems](StatesOperators.ipynb#qubit)
#     - [Expectation Values](StatesOperators.ipynb#expect)
#     - [Super Operators and Vectorized Operators](StatesOperators.ipynb#super)
# - [Tensor Products and Partial Traces](TensorPtrace.ipynb)
#     - [Tensor Products](TensorPtrace.ipynb#tensor)
#     - [Partial Trace](TensorPtrace.ipynb#partial)
#     - [Super Operators and Tensor Manipulations](TensorPtrace.ipynb#super)
# - [Time Evolution & Quantum Dynamics](#contributing)
#     - [Accessing Simulation Results]()
#     - [Lindblad Master Equation]()
#     - [Monte Carlo Simulations]()
#     - [Time-Dependent Hamiltonians]()
#     - [Stochastic Solver]()
#     - [Bloch-Redfield Master Equation]()
#     - [Floquet Formalism]()
#     - [Setting Options for Dynamics Solvers]()
# - [Steady State Solutions](SteadyState.ipynb)
#     - [Introduction](SteadyState.ipynb#intro)
#     - [Steady State Solvers in QuTiP](SteadyState.ipynb#steady)
#     - [Using the Steady State Solvers](SteadyState.ipynb#using)
#     - [Additional Solver Arguments](SteadyState.ipynb#args)
#     - [Example: Harmonic Oscillator in Thermal Bath](SteadyState.ipynb#example)
# - [Eseries Class](Eseries.ipynb)
#     - [Exponential Series Respresentation of Time-Dependent Quantum Objects](Eseries.ipynb#exponential)
#     - [Applications of the Exponential Series](Eseries.ipynb#applications)
# - [Correlation Functions](CorrelationFunctions.ipynb)
#     - [Two-Time Correlation Functions](CorrelationFunctions.ipynb#twotime)
#     - [Steady State Correlation Function](CorrelationFunctions.ipynb#steady)
#     - [Emission Spectrum](CorrelationFunctions.ipynb#emission)
#     - [Non-Steady State Correlation Function](CorrelationFunctions.ipynb#nonsteady)
# - [Bloch Sphere]()
#     - [Introduction]()
#     - [The Bloch and Bloch3D Classes]()
#     - [Configuring The Bloch Sphere]()
#     - [Animating with the Bloch Sphere]()
# - [Visualizing Quantum States & Processes]()
#     - [Fock State Basis Probability Distribution]()
#     - [Quasi-Probability Distributions]()
#     - [Visualizing Operators]()
#     - [Quantum Process Tomography]()
# - [Parallel Computations](Parallel.ipynb)
#     - [Introduction](Parallel.ipynb#intro)
#     - [Single-Variable Functions](Parallel.ipynb#single)
#     - [Multi-Variable Functions](Parallel.ipynb#multi)
#     - [IPython-Based Parallel Processing](Parallel.ipynb#ipython)
# - [Saving QuTiP Objects and Data Sets]()
#     - [Storing and Loading QuTiP Objects]()
#     - [Storing And Loading Data Sets]()
# - [Random Quantum Objects]()
#     - [Random Composite Objects]()
# - [Modifying Internal Settings]()
#     - [User Accesible Parameters]()
#     - [Example: Changing Settings]()
#     - [Persistant Settings]()

# %%
from IPython.core.display import HTML
def css_styling():
    styles = open("../styles/guide.css", "r").read()
    return HTML(styles)
css_styling()
# Out:
# <style>
# @import url('http://fonts.googleapis.com/css?family=Source+Sans+Pro');
# @import url('http://fonts.googleapis.com/css?family=Source+Code+Pro');
#
# body {
#     -webkit-font-smoothing: antialiased;
#     font-family: "Source Sans Pro", Helvetica, Arial, Verdana, sans-serif;
# }
#
#
# div.cell{
#     width:768px;
#     margin-left:10% !important;
#     margin-right:auto;
# }
# h1 {
#     font-family: "Source Sans Pro", ,Helvetica, Arial, serif;
#
# }
#
# h4{
#     font-family: "Source Sans Pro", Helvetica, Arial, serif;
# 	margin-top:12px;
#     margin-bottom: 3px;
#    }
#
#
# div.text_cell_render{
#     font-family: "Source Sans Pro", Helvetica, Arial, sans-serif;
#     line-height: 125%;
#     font-size: 110%;
#     width:768px;
#     margin-left:auto;
#     margin-right:auto;
# }
#
# div.cell.code_cell { /* area that contains code + output */
#     background: #fff;
#     border: none;
#     border-radius: 10px;
#     padding-top: 1ex;
# }
#
# ...
